# %% [markdown]
# ### Acknowledgement
#
# Upon building the final model we use for the result of the competition, we consulted [TensorFlow tutorials](https://www.tensorflow.org/text/tutorials/transformer) and PyTorch tutorials with practical examples such as [Language Modeling](https://pytorch.org/tutorials/beginner/transformer_tutorial.html) and [Language Translation](https://pytorch.org/tutorials/beginner/translation_transformer.html.)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, os.path 
import numpy as np
import pickle
from glob import glob
import pandas as pd
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
import time
from tqdm.notebook import tqdm
import math
import random

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

"""
    number of trajectories in each city
    # austin --  train: 43041 test: 6325 
    # miami -- train: 55029 test:7971
    # pittsburgh -- train: 43544 test: 6361
    # dearborn -- train: 24465 test: 3671
    # washington-dc -- train: 25744 test: 3829
    # palo-alto -- train:  11993 test:1686

    trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds
"""
ROOT_PATH = "./"
cities = ["austin", "miami", "pittsburgh", "dearborn", "washington-dc", "palo-alto"]
splits = ["train", "test"]

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(DEVICE)
# Out:
# cuda:0

# %% [markdown]
# ## Create a Torch.Dataset class for the training dataset

# %%
def get_rotation_matrix(inputs, device=DEVICE): 
    vectors = inputs[:, 1, :]
    matrices = torch.zeros((vectors.shape[0], 2, 2)).to(device).float()
    for i in range(vectors.shape[0]):
        matrices[i] = rotate_matrix(vectors[i]).to(device)
    return matrices

def rotate_matrix(v, device=DEVICE):
    """
    Rotates the vector into the (1, 1) direction
    """    
    a, b = v
    norm = torch.linalg.norm(v)
    if norm == 0:
        Q1 = torch.eye(2).to(device)
    else:
        Q1 = torch.tensor([[a, b], [-b, a]]).to(device) / torch.linalg.norm(v)
    Q2 = torch.tensor([[1, -1], [1, 1]]).to(device) / torch.sqrt(torch.tensor(2).to(device))
    
    return Q2.float() @ Q1.float()

# %%
# def normalize(A, Q, T):
#     return torch.matmul((A - T.unsqueeze(1)), Q.T)

def revert(A, Q, T):
    return torch.matmul(A, Q) + T.unsqueeze(1)

# %%
class ArgoverseDataset(Dataset):
    """Dataset class for Argoverse"""
    def __init__(self, city: str, split:str, transform=False, normalize=False):
        super(ArgoverseDataset, self).__init__()
        self.transform = transform
        self.normalize = normalize
        self.split = split
        self.inputs, self.outputs = self.get_city_trajectories(city=city, split=split)

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        if self.split == 'train':       
            data = (self.inputs[idx], self.outputs[idx])
            return data     
        return self.inputs[idx]
    
    def get_city_trajectories(self, city="palo-alto", split="train", device=DEVICE):
        assert city in cities and split in splits

        # get input
        f_in = ROOT_PATH + split + "/" + city + "_inputs"
        inputs = pickle.load(open(f_in, "rb"))
        inputs = torch.tensor(inputs).to(device).float()

        # store input starting positions and rotation matrix
        self.T0 = inputs[:, 0, :].clone()

        # normalize inputs
        if self.normalize:     
            # translation
            inputs = inputs - self.T0.unsqueeze(1)
            
            # rotation
            self.Q0 = get_rotation_matrix(inputs)
            inputs = torch.matmul(inputs, self.Q0.transpose(1, 2))

        # get outputs
        outputs = None
        if split == "train":
            # get outputs
            f_out = ROOT_PATH + split + "/" + city + "_outputs"
            outputs = pickle.load(open(f_out, "rb"))
            outputs = torch.tensor(outputs).to(device).float()
            
            # normalize outputs
            if self.normalize:      
                # translation
                outputs = outputs - self.T0.unsqueeze(1)
                    
                # rotation
                outputs = torch.matmul(outputs, self.Q0.transpose(1, 2))
        return inputs, outputs

# %%
# intialize a dataset
city = 'palo-alto' 
split = 'train' #'test' #'train'
train_dataset = ArgoverseDataset(city = city, split = split, transform=False, normalize=True)
original_dataset = ArgoverseDataset(city = city, split = split, transform=False, normalize=False)

len(train_dataset)
# Out:
# 11993

# %% [markdown]
# ## Create a DataLoader class for training

# %%
batch_sz = 4  # batch size 
train_loader = DataLoader(train_dataset, batch_size=batch_sz, drop_last=True)
original_loader = DataLoader(original_dataset, batch_size=batch_sz, drop_last=True)
train_single_loader = DataLoader(train_dataset, batch_size=1, drop_last=True)
original_single_loader = DataLoader(original_dataset, batch_size=1, drop_last=True)

len(train_loader)
# Out:
# 2998

# %% [markdown]
# ## Sample a batch of data and visualize

# %%
def show_sample_batch(sample_batch):
    """visualize the trajectory for a batch of samples"""
    inp, out = sample_batch
    inp = inp.cpu().detach().numpy()
    out = out.cpu().detach().numpy()
    batch_sz, agent_sz = inp.shape[0], inp.shape[1]
    
    if batch_sz > 1:
        fig, axs = plt.subplots(1, batch_sz, figsize=(15, 3), facecolor='w', edgecolor='k')
        fig.subplots_adjust(hspace=.2, wspace=.5)
        axs = axs.ravel()   
        for i in range(4):
            axs[i].xaxis.set_ticks([inp[i,0,0],
                                       inp[i,-1,0], out[i,-1,0]])
            axs[i].yaxis.set_ticks([inp[i,0,1],
                                       inp[i,-1,1], out[i,-1,1]])

            # first two feature dimensions are (x,y) positions
            axs[i].scatter(inp[i,:,0], inp[i,:,1])
            axs[i].scatter(out[i,:,0], out[i,:,1])
    else:
        plt.scatter(inp[0,:,0], inp[0,:,1])
        plt.scatter(out[0,:,0], out[0,:,1])

# %%
for i_batch, data in enumerate(train_loader):
    if i_batch < 20:
        continue
    show_sample_batch(data)
    break

# %% [markdown]
# ## Transformer

# %%
class TransAutoReg(nn.Module):
    def __init__(
        self,
        batch_size,
        model_dim,
        conv_depth=16,
        kernel_size=4,
        conv_padding=3,
        n_heads=8, 
        linear_dim=256, 
        dropout_rate=0.1, 
        encoder_layers=1,
        input_dim=2,
        regress_steps=4
    ):
        super(TransAutoReg, self).__init__()
        self.batch_size = batch_size
        self.model_dim = model_dim
        self.conv_depth = conv_depth
        self.kernel_size = kernel_size
        self.conv_padding = conv_padding
        self.n_heads = n_heads
        self.linear_dim = linear_dim
        self.dropout_rate = dropout_rate
        self.encoder_layers = encoder_layers
        self.input_dim = input_dim
        self.regress_steps = regress_steps
        self.input_length = 50
        self.output_length = 60 // regress_steps
        
        # compute convolution output size
        size_1 = self.input_length + 2 * conv_padding - kernel_size + 1
        size_2 = size_1 + 2 * conv_padding - kernel_size + 1
        self.conv_outsize = (size_2 - kernel_size) // 2 + 1
        
        # input convolution
        self.input_convolution = nn.Sequential(
            nn.Conv1d(input_dim, conv_depth, kernel_size=kernel_size, padding=conv_padding),
            nn.LeakyReLU(),
            nn.Conv1d(conv_depth, conv_depth, kernel_size=kernel_size, padding=conv_padding),
            nn.LeakyReLU(),
            nn.MaxPool1d(kernel_size=kernel_size, stride=2, padding=0)
        )  
        self.input_projection = nn.Linear(conv_depth, model_dim)
        
        # encoder
        encoder = nn.TransformerEncoderLayer(
            d_model=model_dim, 
            nhead=n_heads, 
            dim_feedforward=linear_dim, 
            dropout=dropout_rate, 
            batch_first=True,
            device=DEVICE
        )
        self.encoder = nn.TransformerEncoder(encoder, num_layers=encoder_layers, norm=None)
        
        # decoder
        self.decoder = nn.Sequential(
            nn.Linear(self.conv_outsize * model_dim, linear_dim),
            nn.LeakyReLU(), 
            nn.Linear(linear_dim, linear_dim),
            nn.LeakyReLU(), 
            nn.Linear(linear_dim, self.output_length * input_dim)
        )
    
    def get_angles(self, pos, i, D):
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(D))
        return pos * angle_rates

    def positional_encoding(self, D, position=110, dim=3, device=DEVICE):
        angle_rads = self.get_angles(np.arange(position)[:, np.newaxis],
                                np.arange(D)[np.newaxis, :],
                                D)
        # apply sin to even indices in the array; 2i
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        # apply cos to odd indices in the array; 2i+1
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        if dim == 3:
            pos_encoding = angle_rads[np.newaxis, ...]
        elif dim == 4:
            pos_encoding = angle_rads[np.newaxis,np.newaxis,  ...]
        return torch.tensor(pos_encoding, device=device)
    
    def one_pass(self, inputs):
        input_pos = self.input_convolution(inputs.transpose(1, 2))
        input_pos = self.input_projection(input_pos.transpose(1, 2))
        input_pos += self.positional_encoding(self.model_dim)[:, :self.conv_outsize, :]
        memory = self.encoder(input_pos).reshape(self.batch_size, -1)
        out = self.decoder(memory)
        return out.reshape(self.batch_size, self.output_length, self.input_dim)
    
    def forward(self, inputs):
        # predict first roll
        step_pred = self.one_pass(inputs)
        inputs = torch.cat((
            inputs,
            step_pred
        ), dim=1)
        
        for step in range(1, self.regress_steps):
            # take chunk
            train_inputs = inputs[:, step * self.output_length:, :]
            
            # normalize
            T_t = train_inputs[:, 0, :].clone()
            train_inputs = train_inputs - T_t.unsqueeze(1)
            
            Q_t = get_rotation_matrix(train_inputs)
            train_inputs = torch.matmul(train_inputs, Q_t.transpose(1, 2))
            
            # autoregress
            step_pred = self.one_pass(train_inputs)
            
            # revert to original scale
            step_pred = revert(step_pred, Q_t, T_t)
            
            # add new predictions
            inputs = torch.cat((
                inputs,
                step_pred
            ), dim=1)
            
        return inputs[:, self.input_length:, :]

# %% [markdown]
# ## Train the Transformer

# %%
def train(
    batch_size, 
    city, 
    model_dim,
    conv_depth,
    kernel_size,
    conv_padding,
    n_heads,
    linear_dim,
    dropout_rate,
    encoder_layers,
    regress_steps,
    num_iters,
    learning_rate,
    factor,
    patience,
    device=DEVICE
):    
    # Create the training/validation set
    train_dataset = ArgoverseDataset(city=city, split='train', transform=False, normalize=True)
    train_sz = int(len(train_dataset) * 0.9)
    val_sz = len(train_dataset) - train_sz
    train_loader, val_loader = torch.utils.data.random_split(train_dataset, [train_sz, val_sz])
    train_loader = DataLoader(train_loader, batch_size=batch_size, drop_last=True)
    val_loader = DataLoader(val_loader, batch_size=batch_size, drop_last=True)
    
    # Initialize the model/optimizer/loss function
    model = TransAutoReg(
        batch_size=batch_size,
        model_dim=model_dim,
        conv_depth=conv_depth,
        kernel_size=kernel_size,
        conv_padding=conv_padding,
        n_heads=n_heads, 
        linear_dim=linear_dim, 
        dropout_rate=dropout_rate, 
        encoder_layers=encoder_layers,
        regress_steps=regress_steps
    ).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) 
    loss_function = nn.MSELoss()
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=factor, patience=patience, verbose=True) 
    
    # Print out how many parameters to train
    param_sizes = [p.numel() for p in model.parameters()]
    print(f"number of weight/biases matrices: {len(param_sizes)} "
          f"for a total of {np.sum(param_sizes)} parameters ")
    
    avg_train_loss, avg_val_loss = [], []
    best_val_score = float('inf')
    
    # Start training
    for epoch in tqdm(list(range(num_iters))):
        print(f'Epoch {epoch+1}')
        print('Training & Validating ', end='')
        
        train_loss, val_loss = [], []
        
        # Training set
        for batches, (X, y) in enumerate(train_loader):
            X = X.to(device).float()
            y = y.to(device).float()
            
            # Track progress
            if (batches + 1) % 20 == 0:
                print('-', end='')
            
            # Forward pass
            optimizer.zero_grad()
            out = model(X)
            
            # Backpropagation
            loss = loss_function(out, y)
            loss.backward()
            optimizer.step()
            train_loss.append(loss.item())
            
            
        print()
        avg_train = np.mean(train_loss)
        avg_train_loss.append(avg_train)
        

        # Evaluate on val set
        with torch.no_grad():
            for X, y in val_loader:
                X = X.to(device).float()
                y = y.to(device).float()
                
                out = model(X)
                loss = loss_function(out, y)
                val_loss.append(loss.item())
                
            avg_val = np.mean(val_loss)
            avg_val_loss.append(avg_val)

        print(f'- Training Loss: {avg_train}')
        print(f'- Validation Loss: {avg_val}')
        print()
        
        scheduler.step(avg_val)
        
        # save better model
        if avg_val < best_val_score:
            best_val_score = avg_val
            torch.save(model, f'TF_Auto_Conv_{city}_0528.pt')
        
    return model, (avg_train_loss, avg_val_loss)

# %%
def plot_loss(start_from, city, split, losses):

    avg_train_loss, avg_val_loss = losses
    plt.plot(np.sqrt(avg_train_loss[start_from:]), label='train_loss')
    plt.plot(np.sqrt(avg_val_loss[start_from:]), label='validation_loss')
    plt.title(f'{city} RMSE {split} Loss vs. Epoch')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
def vis_results(city, split, batch_size, model, idx, device=DEVICE):
    train_dataset = ArgoverseDataset(city = city, split = split, transform=False, normalize=True)
    train_loader = DataLoader(train_dataset, batch_size=batch_size)
    
    with torch.no_grad():
        for X, y in train_loader:
            X = X.to(device).float()
            y = y.to(device).float()

            out = model(X).reshape(batch_size, -1, 2)
            break
    
    X = X.cpu()
    y = y.cpu()
    out = out.cpu()
    
    Q = train_dataset.Q0[idx].cpu()
    T = train_dataset.T0[idx].cpu()
    X = X[idx] @ Q + T
    y = y[idx] @ Q + T
    out = out[idx] @ Q + T
    
    plt.scatter(X[:, 0], X[:, 1], label='seed')
    plt.scatter(y[:, 0], y[:, 1], label='ground truth')
    plt.scatter(out[:, 0], out[:, 1], label='prediction')
    plt.title(f'Random Sample From {city}_{split} Projectile Visualization')
    plt.legend()
    plt.show()

# %%
def vis_test(city, split, batch_sz, model, idx, norm_viz=True):
    '''
    This is the last batch, which is usually not complete and need to fill with 0s.
    Check if I convert the prediction back correctly or not
    '''
    
    # Create the dataset for testing
    test_dataset = ArgoverseDataset(city = city, split = split,
                                    transform=False, normalized=True)
        
    test_loader = DataLoader(test_dataset, batch_size=batch_sz)
    
    with torch.no_grad():
        for X in test_loader:
            if len(X) == batch_sz:
                continue
            print(len(X))
            to_fill = np.zeros([batch_sz-len(X), 50, 2])
            X = torch.from_numpy(np.append(X, to_fill, axis=0)).float()
            X = X.to(device).float()
            S = X.shape[1]
            mask = create_look_ahead_mask(S)

            output = model(X, mask)[0].reshape(batch_size, -1, 2)

            X = X.cpu()
            output = output.cpu()

            if norm_viz:
                plt.scatter(X[idx, :, 0], X[idx, :, 1], label='input')
                plt.scatter(output[idx, :, 0], output[idx, :, 1], label='pred')
                plt.legend()
                plt.show()
            else:
                rotation =  test_dataset.rotate_matrix[-1].T
                X[idx] = X[idx] @ np.linalg.inv(rotation)
                X[idx] = X[idx] + test_dataset.start_pos[-1, : ]
                output[idx] = output[idx] @ np.linalg.inv(rotation)
                output[idx] = output[idx] + test_dataset.start_pos[-1, : ]

                plt.scatter(X[idx, :, 0], X[idx, :, 1], label='input')
                plt.scatter(output[idx, :, 0], output[idx, :, 1], label='pred')
                plt.legend()
                plt.show()

# %%
def make_pred(test_loader, batch_sz, model):
    '''
    Remember to use test_dataset stats, NOT train_dataset
    '''
    count_row = 0
    out = []

    for X in test_loader:
        if len(X) != batch_sz:
            print(len(X))
            to_fill = np.zeros([batch_sz-len(X), 50, 2])
            X = torch.from_numpy(np.append(X, to_fill, axis=0))
            
#             a = test_dataset.rotate_matrix[-1].T
#             temp = X[20]@np.linalg.inv(a) + test_dataset.start_pos[-1]
#             plt.scatter(temp[:, 0], temp[:, 1], label='input')

        X = X.to(device).float()
    
        S = X.shape[1]
        mask = create_look_ahead_mask(S)

        pred = model(X, mask)[0].reshape(batch_size, -1, 2).cpu().detach().numpy()

        for i in range(batch_sz):
            if count_row >= len(test_dataset):
                break
                
#             if count_row == (len(test_dataset) - 1):
#                 plt.scatter(X[i, :, 0], X[i, :, 1], label='input')
#                 plt.scatter(pred[i, :, 0], pred[i, :, 1], label='pred')
#                 plt.legend()
#                 plt.show()

            rotation =  test_dataset.rotate_matrix[count_row].T
            pred[i] = pred[i] @ np.linalg.inv(rotation)
            pred[i] = pred[i] + test_dataset.start_pos[count_row, : ]

    #         print(pred[i, 0, :])
                
            out.append(pred[i])
            count_row += 1 
            
    #         print(count_row)
    #         print(pred[0, :5, :])

    out = np.array(out).reshape(len(test_dataset), -1)

    return out

# %% [markdown]
# ### palo-alto

# %%
# Hyperparameter
batch_size = 32
city = 'palo-alto'
model_dim = 16
conv_depth = 16
kernel_size = 3
conv_padding = 2
n_heads = 8
linear_dim = 32 # [32, 128]
dropout_rate = 0 # [0, 0.5]
encoder_layers = 2
num_iters = 100 # [50, 100]
learning_rate = 0.002 # [0.001, 0.005]
factor = 0.5 # 0.1 ~ 0.99
patience = 2
regress_steps = 3

palo_net, palo_loss = train(
    batch_size, 
    city, 
    model_dim,
    conv_depth,
    kernel_size,
    conv_padding,
    n_heads,
    linear_dim,
    dropout_rate,
    encoder_layers,
    regress_steps,
    num_iters,
    learning_rate,
    factor,
    patience,
    device=DEVICE
)
# Out:
# number of weight/biases matrices: 36 for a total of 21336 parameters
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1
# Training & Validating ----------------
# - Training Loss: 224.36623596508355
# - Validation Loss: 98.0727215328732
#
# Epoch 2
# Training & Validating ----------------
# - Training Loss: 89.27125832305818
# - Validation Loss: 87.5918837882377
#
# Epoch 3
# Training & Validating ----------------
# - Training Loss: 82.28231347420802
# - Validation Loss: 76.92877558115366
#
# Epoch 4
# Training & Validating ----------------
# - Training Loss: 73.22441065417553
# - Validation Loss: 74.11217735909126
#
# Epoch 5
# Training & Validating ----------------
# - Training Loss: 70.37455608017014
# - Validation Loss: 66.54308525291648
#
# Epoch 6
# Training & Validating ----------------
# - Training Loss: 66.7913030856441
# - Validation Loss: 68.57244682312012
#
# Epoch 7
# Training & Validating ----------------
# - Training Loss: 64.7745619471066
# - Validation Loss: 64.93736102129962
#
# Epoch 8
# Training & Validating ----------------
# - Training Loss: 60.60189058094421
# - Validation Loss: 57.811628187024915
#
# Epoch 9
# Training & Validating ----------------
# - Training Loss: 52.221167725696056
# - Validation Loss: 59.927738292797194
#
# Epoch 10
# Training & Validating ----------------
# - Training Loss: 43.35864141220863
# - Validation Loss: 43.52798642338933
#
# Epoch 11
# Training & Validating ----------------
# - Training Loss: 39.28100692907498
# - Validation Loss: 42.09019681569692
#
# Epoch 12
# Training & Validating ----------------
# - Training Loss: 35.815923764373146
# - Validation Loss: 38.09921491468275
#
# Epoch 13
# Training & Validating ----------------
# - Training Loss: 34.32098643928324
# - Validation Loss: 34.14766234320563
#
# Epoch 14
# Training & Validating ----------------
# - Training Loss: 33.44793664383251
# - Validation Loss: 37.8257207097234
#
# Epoch 15
# Training & Validating ----------------
# - Training Loss: 32.4302199162786
# - Validation Loss: 36.30917167663574
#
# Epoch 16
# Training & Validating ----------------
# - Training Loss: 32.14335002955768
# - Validation Loss: 33.18618496044262
#
# Epoch 17
# Training & Validating ----------------
# - Training Loss: 30.371532779772842
# - Validation Loss: 30.768364571236276
#
# Epoch 18
# Training & Validating ----------------
# - Training Loss: 30.630606504151658
# - Validation Loss: 30.465459565858584
#
# Epoch 19
# Training & Validating ----------------
# - Training Loss: 29.961560215369882
# - Validation Loss: 38.647833489082956
#
# Epoch 20
# Training & Validating ----------------
# - Training Loss: 29.771656574056834
# - Validation Loss: 29.51348572808343
#
# Epoch 21
# Training & Validating ----------------
# - Training Loss: 29.109846072663892
# - Validation Loss: 29.540430558694375
#
# Epoch 22
# Training & Validating ----------------
# - Training Loss: 29.000459668190615
# - Validation Loss: 29.57597201579326
#
# Epoch 23
# Training & Validating ----------------
# - Training Loss: 28.743442125065744
# - Validation Loss: 32.39050282658757
#
# Epoch    23: reducing learning rate of group 0 to 1.0000e-03.
# Epoch 24
# Training & Validating ----------------
# - Training Loss: 25.003998235708174
# - Validation Loss: 26.24611186981201
#
# Epoch 25
# Training & Validating ----------------
# - Training Loss: 24.321178308934062
# - Validation Loss: 25.57760883021999
#
# Epoch 26
# Training & Validating ----------------
# - Training Loss: 24.65789175175064
# - Validation Loss: 25.694295625428897
#
# Epoch 27
# Training & Validating ----------------
# - Training Loss: 24.216889313491233
# - Validation Loss: 24.397536612845755
#
# Epoch 28
# Training & Validating ----------------
# - Training Loss: 24.348445487659127
# - Validation Loss: 25.30557137566644
#
# Epoch 29
# Training & Validating ----------------
# - Training Loss: 23.944338917378502
# - Validation Loss: 25.68460358800115
#
# Epoch 30
# Training & Validating ----------------
# - Training Loss: 24.06445785941285
# - Validation Loss: 25.050780992250186
#
# Epoch    30: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 31
# Training & Validating ----------------
# - Training Loss: 22.516442969574065
# - Validation Loss: 23.86207034136798
#
# Epoch 32
# Training & Validating ----------------
# - Training Loss: 21.95098634714189
# - Validation Loss: 23.552817267340583
#
# Epoch 33
# Training & Validating ----------------
# - Training Loss: 21.868878783387316
# - Validation Loss: 23.238353136423473
#
# Epoch 34
# Training & Validating ----------------
# - Training Loss: 21.65684495127873
# - Validation Loss: 23.621272087097168
#
# Epoch 35
# Training & Validating ----------------
# - Training Loss: 21.653081418498687
# - Validation Loss: 23.391355488751387
#
# Epoch 36
# Training & Validating ----------------
# - Training Loss: 21.381472731910048
# - Validation Loss: 22.668959385639912
#
# Epoch 37
# Training & Validating ----------------
# - Training Loss: 21.20616744463097
# - Validation Loss: 23.010758657713193
#
# Epoch 38
# Training & Validating ----------------
# - Training Loss: 21.38542159162572
# - Validation Loss: 23.15646743774414
#
# Epoch 39
# Training & Validating ----------------
# - Training Loss: 21.17340098927212
# - Validation Loss: 23.15839249378926
#
# Epoch    39: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 40
# Training & Validating ----------------
# - Training Loss: 20.56860720863682
# - Validation Loss: 22.514180879335147
#
# Epoch 41
# Training & Validating ----------------
# - Training Loss: 20.250162492520023
# - Validation Loss: 22.66474942903261
#
# Epoch 42
# Training & Validating ----------------
# - Training Loss: 20.156593311434328
# - Validation Loss: 22.26088709444613
#
# Epoch 43
# Training & Validating ----------------
# - Training Loss: 20.022877192285012
# - Validation Loss: 22.171791076660156
#
# Epoch 44
# Training & Validating ----------------
# - Training Loss: 19.948422502693152
# - Validation Loss: 22.22455207721607
#
# Epoch 45
# Training & Validating ----------------
# - Training Loss: 19.815713489091006
# - Validation Loss: 22.250533954517262
#
# Epoch 46
# Training & Validating ----------------
# - Training Loss: 19.874182658662427
# - Validation Loss: 22.474415083189268
#
# Epoch    46: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 47
# Training & Validating ----------------
# - Training Loss: 19.441904178359035
# - Validation Loss: 21.855384079185693
#
# Epoch 48
# Training & Validating ----------------
# - Training Loss: 19.374973532000354
# - Validation Loss: 21.698475219107962
#
# Epoch 49
# Training & Validating ----------------
# - Training Loss: 19.25620845092864
# - Validation Loss: 21.80599730723613
#
# Epoch 50
# Training & Validating ----------------
# - Training Loss: 19.155001275263484
# - Validation Loss: 21.724478824718577
#
# Epoch 51
# Training & Validating ----------------
# - Training Loss: 19.122990486529886
# - Validation Loss: 21.619050721864443
#
# Epoch 52
# Training & Validating ----------------
# - Training Loss: 19.07413521435565
# - Validation Loss: 21.600560136743493
#
# Epoch 53
# Training & Validating ----------------
# - Training Loss: 19.04862681765231
# - Validation Loss: 21.50670453664419
#
# Epoch 54
# Training & Validating ----------------
# - Training Loss: 18.957894033777254
# - Validation Loss: 21.5621192777479
#
# Epoch 55
# Training & Validating ----------------
# - Training Loss: 18.93041445451957
# - Validation Loss: 21.639116261456465
#
# Epoch 56
# Training & Validating ----------------
# - Training Loss: 18.890726938445773
# - Validation Loss: 21.592728666357093
#
# Epoch    56: reducing learning rate of group 0 to 6.2500e-05.
# Epoch 57
# Training & Validating ----------------
# - Training Loss: 18.71006250239975
# - Validation Loss: 21.407464388254528
#
# Epoch 58
# Training & Validating ----------------
# - Training Loss: 18.603657179133474
# - Validation Loss: 21.42846682264998
#
# Epoch 59
# Training & Validating ----------------
# - Training Loss: 18.57845233102227
# - Validation Loss: 21.353777627687197
#
# Epoch 60
# Training & Validating ----------------
# - Training Loss: 18.532679543650822
# - Validation Loss: 21.315383627608014
#
# Epoch 61
# Training & Validating ----------------
# - Training Loss: 18.510518889045148
# - Validation Loss: 21.33637033926474
#
# Epoch 62
# Training & Validating ----------------
# - Training Loss: 18.485823501111494
# - Validation Loss: 21.279215090983623
#
# Epoch 63
# Training & Validating ----------------
# - Training Loss: 18.477500658006978
# - Validation Loss: 21.299245860125566
#
# Epoch 64
# Training & Validating ----------------
# - Training Loss: 18.448521690481847
# - Validation Loss: 21.383036304164577
#
# Epoch 65
# Training & Validating ----------------
# - Training Loss: 18.406217914660537
# - Validation Loss: 21.339369361465042
#
# Epoch    65: reducing learning rate of group 0 to 3.1250e-05.
# Epoch 66
# Training & Validating ----------------
# - Training Loss: 18.313462806384713
# - Validation Loss: 21.44018840789795
#
# Epoch 67
# Training & Validating ----------------
# - Training Loss: 18.258281509671082
# - Validation Loss: 21.349825034270417
#
# Epoch 68
# Training & Validating ----------------
# - Training Loss: 18.231521946032608
# - Validation Loss: 21.323619507454538
#
# Epoch    68: reducing learning rate of group 0 to 1.5625e-05.
# Epoch 69
# Training & Validating ----------------
# - Training Loss: 18.180486152716842
# - Validation Loss: 21.2082735783345
#
# Epoch 70
# Training & Validating ----------------
# - Training Loss: 18.143192449733835
# - Validation Loss: 21.18839779415646
#
# Epoch 71
# Training & Validating ----------------
# - Training Loss: 18.12629583964362
# - Validation Loss: 21.179229916752995
#
# Epoch 72
# Training & Validating ----------------
# - Training Loss: 18.12002655448121
# - Validation Loss: 21.166385006260228
#
# Epoch 73
# Training & Validating ----------------
# - Training Loss: 18.108478563121942
# - Validation Loss: 21.16103185189737
#
# Epoch 74
# Training & Validating ----------------
# - Training Loss: 18.099633137620874
# - Validation Loss: 21.173146196313805
#
# Epoch 75
# Training & Validating ----------------
# - Training Loss: 18.086988650019162
# - Validation Loss: 21.156769365877718
#
# Epoch 76
# Training & Validating ----------------
# - Training Loss: 18.076236076807763
# - Validation Loss: 21.170300715678447
#
# Epoch 77
# Training & Validating ----------------
# - Training Loss: 18.06777159184306
# - Validation Loss: 21.1563957832955
#
# Epoch 78
# Training & Validating ----------------
# - Training Loss: 18.058113833917
# - Validation Loss: 21.15221188519452
#
# Epoch 79
# Training & Validating ----------------
# - Training Loss: 18.049003649182417
# - Validation Loss: 21.155753109906172
#
# Epoch 80
# Training & Validating ----------------
# - Training Loss: 18.038697950210345
# - Validation Loss: 21.152913969916266
#
# Epoch 81
# Training & Validating ----------------
# - Training Loss: 18.034653768341336
# - Validation Loss: 21.162091693362676
#
# Epoch    81: reducing learning rate of group 0 to 7.8125e-06.
# Epoch 82
# Training & Validating ----------------
# - Training Loss: 18.009322858351982
# - Validation Loss: 21.12768660364924
#
# Epoch 83
# Training & Validating ----------------
# - Training Loss: 17.990436998248455
# - Validation Loss: 21.12679960921004
#
# Epoch 84
# Training & Validating ----------------
# - Training Loss: 17.9834210582586
# - Validation Loss: 21.121061247748298
#
# Epoch 85
# Training & Validating ----------------
# - Training Loss: 17.97671718201227
# - Validation Loss: 21.115007555162585
#
# Epoch 86
# Training & Validating ----------------
# - Training Loss: 17.970964615705814
# - Validation Loss: 21.108604740452122
#
# Epoch 87
# Training & Validating ----------------
# - Training Loss: 17.96779372076606
# - Validation Loss: 21.10690199362265
#
# Epoch 88
# Training & Validating ----------------
# - Training Loss: 17.961786234767924
# - Validation Loss: 21.105979970983558
#
# Epoch 89
# Training & Validating ----------------
# - Training Loss: 17.956323330763187
# - Validation Loss: 21.101758029009844
#
# Epoch 90
# Training & Validating ----------------
# - Training Loss: 17.95232491818663
# - Validation Loss: 21.103172817745723
#
# Epoch 91
# Training & Validating ----------------
# - Training Loss: 17.946847652469263
# - Validation Loss: 21.101451023204906
#
# Epoch 92
# Training & Validating ----------------
# - Training Loss: 17.942412069360298
# - Validation Loss: 21.0968338476645
#
# Epoch 93
# Training & Validating ----------------
# - Training Loss: 17.936819222277634
# - Validation Loss: 21.096935890816354
#
# Epoch 94
# Training & Validating ----------------
# - Training Loss: 17.932449480900072
# - Validation Loss: 21.100009840887946
#
# Epoch 95
# Training & Validating ----------------
# - Training Loss: 17.928761168120523
# - Validation Loss: 21.104379937455462
#
# Epoch    95: reducing learning rate of group 0 to 3.9063e-06.
# Epoch 96
# Training & Validating ----------------
# - Training Loss: 17.916878318220643
# - Validation Loss: 21.0881344821002
#
# Epoch 97
# Training & Validating ----------------
# - Training Loss: 17.904965958184942
# - Validation Loss: 21.090282208210713
#
# Epoch 98
# Training & Validating ----------------
# - Training Loss: 17.901906856797215
# - Validation Loss: 21.090761262017327
#
# Epoch 99
# Training & Validating ----------------
# - Training Loss: 17.898444294575768
# - Validation Loss: 21.087477323171253
#
# Epoch    99: reducing learning rate of group 0 to 1.9531e-06.
# Epoch 100
# Training & Validating ----------------
# - Training Loss: 17.88708421101556
# - Validation Loss: 21.089028590434307

# %%
vis_results('palo-alto', 'train', 32, palo_net, 29)
