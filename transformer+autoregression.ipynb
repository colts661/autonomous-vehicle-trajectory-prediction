# %% [markdown]
# ### Acknowledgement
#
# Upon building the final model we use for the result of the competition, we consulted [TensorFlow tutorials](https://www.tensorflow.org/text/tutorials/transformer) and PyTorch tutorials with practical examples such as [Language Modeling](https://pytorch.org/tutorials/beginner/transformer_tutorial.html) and [Language Translation](https://pytorch.org/tutorials/beginner/translation_transformer.html.)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, os.path 
import numpy as np
import pickle
from glob import glob
import pandas as pd
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
import time
from tqdm.notebook import tqdm
import math
import random

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

"""
    number of trajectories in each city
    # austin --  train: 43041 test: 6325 
    # miami -- train: 55029 test:7971
    # pittsburgh -- train: 43544 test: 6361
    # dearborn -- train: 24465 test: 3671
    # washington-dc -- train: 25744 test: 3829
    # palo-alto -- train:  11993 test:1686

    trajectories sampled at 10HZ rate, input 5 seconds, output 6 seconds
"""
ROOT_PATH = "./"
cities = ["austin", "miami", "pittsburgh", "dearborn", "washington-dc", "palo-alto"]
splits = ["train", "test"]

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(DEVICE)
# Out:
# cuda:0

# %% [markdown]
# ## Create a Torch.Dataset class for the training dataset

# %%
def get_rotation_matrix(inputs, device=DEVICE): 
    vectors = inputs[:, 1, :]
    matrices = torch.zeros((vectors.shape[0], 2, 2)).to(device).float()
    for i in range(vectors.shape[0]):
        matrices[i] = rotate_matrix(vectors[i]).to(device)
    return matrices

def rotate_matrix(v, device=DEVICE):
    """
    Rotates the vector into the (1, 1) direction
    """    
    a, b = v
    norm = torch.linalg.norm(v)
    if norm == 0:
        Q1 = torch.eye(2).to(device)
    else:
        Q1 = torch.tensor([[a, b], [-b, a]]).to(device) / torch.linalg.norm(v)
    Q2 = torch.tensor([[1, -1], [1, 1]]).to(device) / torch.sqrt(torch.tensor(2).to(device))
    
    return Q2.float() @ Q1.float()

# %%
# def normalize(A, Q, T):
#     return torch.matmul((A - T.unsqueeze(1)), Q.T)

def revert(A, Q, T):
    return torch.matmul(A, Q) + T.unsqueeze(1)

# %%
class ArgoverseDataset(Dataset):
    """Dataset class for Argoverse"""
    def __init__(self, city: str, split:str, transform=False, normalize=False):
        super(ArgoverseDataset, self).__init__()
        self.transform = transform
        self.normalize = normalize
        self.split = split
        self.inputs, self.outputs = self.get_city_trajectories(city=city, split=split)

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        if self.split == 'train':       
            data = (self.inputs[idx], self.outputs[idx])
            return data     
        return self.inputs[idx]
    
    def get_city_trajectories(self, city="palo-alto", split="train", device=DEVICE):
        assert city in cities and split in splits

        # get input
        f_in = ROOT_PATH + split + "/" + city + "_inputs"
        inputs = pickle.load(open(f_in, "rb"))
        inputs = torch.tensor(inputs).to(device).float()

        # store input starting positions and rotation matrix
        self.T0 = inputs[:, 0, :].clone()

        # normalize inputs
        if self.normalize:     
            # translation
            inputs = inputs - self.T0.unsqueeze(1)
            
            # rotation
            self.Q0 = get_rotation_matrix(inputs)
            inputs = torch.matmul(inputs, self.Q0.transpose(1, 2))

        # get outputs
        outputs = None
        if split == "train":
            # get outputs
            f_out = ROOT_PATH + split + "/" + city + "_outputs"
            outputs = pickle.load(open(f_out, "rb"))
            outputs = torch.tensor(outputs).to(device).float()
            
            # normalize outputs
            if self.normalize:      
                # translation
                outputs = outputs - self.T0.unsqueeze(1)
                    
                # rotation
                outputs = torch.matmul(outputs, self.Q0.transpose(1, 2))
        return inputs, outputs

# %%
# intialize a dataset
city = 'palo-alto' 
split = 'train' #'test' #'train'
train_dataset = ArgoverseDataset(city = city, split = split, transform=False, normalize=True)
original_dataset = ArgoverseDataset(city = city, split = split, transform=False, normalize=False)

len(train_dataset)
# Out:
# 11993

# %% [markdown]
# ## Create a DataLoader class for training

# %%
batch_sz = 4  # batch size 
train_loader = DataLoader(train_dataset, batch_size=batch_sz, drop_last=True)
original_loader = DataLoader(original_dataset, batch_size=batch_sz, drop_last=True)
train_single_loader = DataLoader(train_dataset, batch_size=1, drop_last=True)
original_single_loader = DataLoader(original_dataset, batch_size=1, drop_last=True)

len(train_loader)
# Out:
# 2998

# %% [markdown]
# ## Sample a batch of data and visualize

# %%
def show_sample_batch(sample_batch):
    """visualize the trajectory for a batch of samples"""
    inp, out = sample_batch
    inp = inp.cpu().detach().numpy()
    out = out.cpu().detach().numpy()
    batch_sz, agent_sz = inp.shape[0], inp.shape[1]
    
    if batch_sz > 1:
        fig, axs = plt.subplots(1, batch_sz, figsize=(4 * batch_sz, 4), facecolor='w', edgecolor='k')
        fig.subplots_adjust(hspace=.2, wspace=0)
        axs = axs.ravel()   
        for i in range(batch_sz):
            axs[i].xaxis.set_ticks([])
            axs[i].yaxis.set_ticks([])

            # first two feature dimensions are (x,y) positions
            axs[i].scatter(inp[i,:,0], inp[i,:,1])
            axs[i].scatter(out[i,:,0], out[i,:,1])
    else:
        plt.scatter(inp[0,:,0], inp[0,:,1])
        plt.scatter(out[0,:,0], out[0,:,1])

# %%
for i_batch, data in enumerate(train_loader):
    if i_batch < 20:
        continue
    show_sample_batch(data)
    break

# %% [markdown]
# ## Transformer

# %%
class TransAutoReg(nn.Module):
    def __init__(
        self,
        batch_size,
        model_dim, 
        n_heads=8, 
        linear_dim=256, 
        dropout_rate=0.1, 
        encoder_layers=1,
        input_dim=2,
        regress_steps=4
    ):
        super(TransAutoReg, self).__init__()
        self.batch_size = batch_size
        self.model_dim = model_dim
        self.n_heads = n_heads
        self.linear_dim = linear_dim
        self.dropout_rate = dropout_rate
        self.encoder_layers = encoder_layers
        self.input_dim = input_dim
        self.regress_steps = regress_steps
        self.input_length = 50
        self.output_length = 60 // regress_steps
        
        # input linear embedding
        self.input_projection = nn.Linear(input_dim, model_dim)
        
        # encoder
        encoder = nn.TransformerEncoderLayer(
            d_model=model_dim, 
            nhead=n_heads, 
            dim_feedforward=linear_dim, 
            dropout=dropout_rate, 
            batch_first=True,
            device=DEVICE
        )
        self.encoder = nn.TransformerEncoder(encoder, num_layers=encoder_layers, norm=None)
        
        # decoder
        self.decoder = nn.Sequential(
            nn.Linear(self.input_length * model_dim, linear_dim),
            nn.LeakyReLU(), 
            nn.Linear(linear_dim, linear_dim),
            nn.LeakyReLU(), 
            nn.Linear(linear_dim, self.output_length * input_dim)
        )
    
    def get_angles(self, pos, i, D):
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(D))
        return pos * angle_rates

    def positional_encoding(self, D, position=110, dim=3, device=DEVICE):
        angle_rads = self.get_angles(np.arange(position)[:, np.newaxis],
                                np.arange(D)[np.newaxis, :],
                                D)
        # apply sin to even indices in the array; 2i
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        # apply cos to odd indices in the array; 2i+1
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        if dim == 3:
            pos_encoding = angle_rads[np.newaxis, ...]
        elif dim == 4:
            pos_encoding = angle_rads[np.newaxis,np.newaxis,  ...]
        return torch.tensor(pos_encoding, device=device)
    
    def one_pass(self, inputs):
        input_pos = self.input_projection(inputs)
        input_pos += self.positional_encoding(self.model_dim)[:, :self.input_length, :]
        memory = self.encoder(input_pos).reshape(self.batch_size, -1)
        out = self.decoder(memory)
        return out.reshape(self.batch_size, self.output_length, self.input_dim)
    
    def forward(self, inputs):
        # predict first roll
        step_pred = self.one_pass(inputs)
        inputs = torch.cat((
            inputs,
            step_pred
        ), dim=1)
        
        for step in range(1, self.regress_steps):
            # take chunk
            train_inputs = inputs[:, step * self.output_length:, :].clone()
            
            # normalize
            T_t = train_inputs[:, 0, :].clone()
            train_inputs = train_inputs - T_t.unsqueeze(1)
            
            Q_t = get_rotation_matrix(train_inputs)
            train_inputs = torch.matmul(train_inputs, Q_t.transpose(1, 2))
            
            # autoregress
            step_pred = self.one_pass(train_inputs)
            
            # revert to original scale
            step_pred = revert(step_pred, Q_t, T_t)
            
            # add new predictions
            inputs = torch.cat((
                inputs,
                step_pred
            ), dim=1)
            
        return inputs[:, self.input_length:, :]

# %% [markdown]
# ## Train the Transformer

# %%
def train(
    batch_size, 
    city, 
    model_dim,
    n_heads,
    linear_dim,
    dropout_rate,
    encoder_layers,
    regress_steps,
    num_iters,
    learning_rate,
    factor,
    patience,
    device=DEVICE
):    
    # Create the training/validation set
    train_dataset = ArgoverseDataset(city=city, split='train', transform=False, normalize=True)
    train_sz = int(len(train_dataset) * 0.9)
    val_sz = len(train_dataset) - train_sz
    train_loader, val_loader = torch.utils.data.random_split(train_dataset, [train_sz, val_sz])
    train_loader = DataLoader(train_loader, batch_size=batch_size, drop_last=True)
    val_loader = DataLoader(val_loader, batch_size=batch_size, drop_last=True)
    
    # Initialize the model/optimizer/loss function
    model = TransAutoReg(
        batch_size=batch_size,
        model_dim=model_dim, 
        n_heads=n_heads, 
        linear_dim=linear_dim, 
        dropout_rate=dropout_rate, 
        encoder_layers=encoder_layers,
        regress_steps=regress_steps
    ).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) 
    loss_function = nn.MSELoss()
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=factor, patience=patience, verbose=True) 
    
    # Print out how many parameters to train
    param_sizes = [p.numel() for p in model.parameters()]
    print(f"number of weight/biases matrices: {len(param_sizes)} "
          f"for a total of {np.sum(param_sizes)} parameters ")
    
    avg_train_loss, avg_val_loss = [], []
    best_val_score = float('inf')
    
    # Start training
    for epoch in tqdm(list(range(num_iters))):
        print(f'Epoch {epoch+1}')
        print('Training & Validating ', end='')
        
        train_loss, val_loss = [], []
        
        # Training set
        for batches, (X, y) in enumerate(train_loader):
            X = X.to(device).float()
            y = y.to(device).float()
            
            # Track progress
            if (batches + 1) % 20 == 0:
                print('-', end='')
            
            # Forward pass
            optimizer.zero_grad()
            out = model(X)
            
            # Backpropagation
            loss = loss_function(out, y)
            loss.backward()
            optimizer.step()
            train_loss.append(loss.item())
            
            
        print()
        avg_train = np.mean(train_loss)
        avg_train_loss.append(avg_train)
        

        # Evaluate on val set
        with torch.no_grad():
            for X, y in val_loader:
                X = X.to(device).float()
                y = y.to(device).float()
                
                out = model(X)
                loss = loss_function(out, y)
                val_loss.append(loss.item())
                
            avg_val = np.mean(val_loss)
            avg_val_loss.append(avg_val)

        print(f'- Training Loss: {avg_train}')
        print(f'- Validation Loss: {avg_val}')
        print()
        
        scheduler.step(avg_val)
        
        # save better model
        if avg_val < best_val_score:
            best_val_score = avg_val
            torch.save(model, f'TFAUTOREG_{city}_0527.pt')
        
    return model, (avg_train_loss, avg_val_loss)

# %%
def plot_loss(start_from, city, split, losses):

    avg_train_loss, avg_val_loss = losses
    plt.plot(np.sqrt(avg_train_loss[start_from:]), label='train_loss')
    plt.plot(np.sqrt(avg_val_loss[start_from:]), label='validation_loss')
    plt.title(f'{city} RMSE {split} Loss vs. Epoch')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
def vis_results(city, split, batch_size, model, idx, device=DEVICE):
    train_dataset = ArgoverseDataset(city = city, split = split, transform=False, normalize=True)
    train_loader = DataLoader(train_dataset, batch_size=batch_size)
    
    with torch.no_grad():
        for X, y in train_loader:
            X = X.to(device).float()
            y = y.to(device).float()

            out = model(X).reshape(batch_size, -1, 2)
            break
    
    X = X.cpu()
    y = y.cpu()
    out = out.cpu()
    
    Q = train_dataset.Q0[idx].cpu()
    T = train_dataset.T0[idx].cpu()
    X = X[idx] @ Q + T
    y = y[idx] @ Q + T
    out = out[idx] @ Q + T
    
    plt.scatter(X[:, 0], X[:, 1], label='seed')
    plt.scatter(y[:, 0], y[:, 1], label='ground truth')
    plt.scatter(out[:, 0], out[:, 1], label='prediction')
    plt.title(f'Random Sample From {city}_{split} Projectile Visualization')
    plt.legend()
    plt.show()

# %%
def vis_test(city, split, batch_sz, model, idx, norm_viz=True):
    '''
    This is the last batch, which is usually not complete and need to fill with 0s.
    Check if I convert the prediction back correctly or not
    '''
    
    # Create the dataset for testing
    test_dataset = ArgoverseDataset(city = city, split = split,
                                    transform=False, normalized=True)
        
    test_loader = DataLoader(test_dataset, batch_size=batch_sz)
    
    with torch.no_grad():
        for X in test_loader:
            if len(X) == batch_sz:
                continue
            print(len(X))
            to_fill = np.zeros([batch_sz-len(X), 50, 2])
            X = torch.from_numpy(np.append(X, to_fill, axis=0)).float()
            X = X.to(device).float()
            S = X.shape[1]
            mask = create_look_ahead_mask(S)

            output = model(X, mask)[0].reshape(batch_size, -1, 2)

            X = X.cpu()
            output = output.cpu()

            if norm_viz:
                plt.scatter(X[idx, :, 0], X[idx, :, 1], label='input')
                plt.scatter(output[idx, :, 0], output[idx, :, 1], label='pred')
                plt.legend()
                plt.show()
            else:
                rotation =  test_dataset.rotate_matrix[-1].T
                X[idx] = X[idx] @ np.linalg.inv(rotation)
                X[idx] = X[idx] + test_dataset.start_pos[-1, : ]
                output[idx] = output[idx] @ np.linalg.inv(rotation)
                output[idx] = output[idx] + test_dataset.start_pos[-1, : ]

                plt.scatter(X[idx, :, 0], X[idx, :, 1], label='input')
                plt.scatter(output[idx, :, 0], output[idx, :, 1], label='pred')
                plt.legend()
                plt.show()

# %%
def make_pred(test_loader, batch_sz, model):
    '''
    Remember to use test_dataset stats, NOT train_dataset
    '''
    count_row = 0
    out = []

    for X in test_loader:
        if len(X) != batch_sz:
            print(len(X))
            to_fill = np.zeros([batch_sz-len(X), 50, 2])
            X = torch.from_numpy(np.append(X, to_fill, axis=0))
            
#             a = test_dataset.rotate_matrix[-1].T
#             temp = X[20]@np.linalg.inv(a) + test_dataset.start_pos[-1]
#             plt.scatter(temp[:, 0], temp[:, 1], label='input')

        X = X.to(device).float()
    
        S = X.shape[1]
        mask = create_look_ahead_mask(S)

        pred = model(X, mask)[0].reshape(batch_size, -1, 2).cpu().detach().numpy()

        for i in range(batch_sz):
            if count_row >= len(test_dataset):
                break
                
#             if count_row == (len(test_dataset) - 1):
#                 plt.scatter(X[i, :, 0], X[i, :, 1], label='input')
#                 plt.scatter(pred[i, :, 0], pred[i, :, 1], label='pred')
#                 plt.legend()
#                 plt.show()

            rotation =  test_dataset.rotate_matrix[count_row].T
            pred[i] = pred[i] @ np.linalg.inv(rotation)
            pred[i] = pred[i] + test_dataset.start_pos[count_row, : ]

    #         print(pred[i, 0, :])
                
            out.append(pred[i])
            count_row += 1 
            
    #         print(count_row)
    #         print(pred[0, :5, :])

    out = np.array(out).reshape(len(test_dataset), -1)

    return out

# %%
debug_loader = DataLoader(train_dataset, batch_size=32, drop_last=True)
for i, data in enumerate(debug_loader):
    X, y = data
    break

# %%
show_sample_batch((X[9:16], y[9:16]))

# %%
out1 = palo_net.one_pass(X)

# %%
X1 = torch.cat((
    X,
    out1
), dim=1)
X1.shape
# Out:
# torch.Size([32, 70, 2])

# %%
X2 = X1[:, 1 * 20:, :].clone()

# %%
X2.shape
# Out:
# torch.Size([32, 50, 2])

# %%
# normalize
T_test = X2[:, 0, :].clone()
X3 = X2 - T_test.unsqueeze(1)

Q_test = get_rotation_matrix(X3)
X4 = torch.matmul(X3, Q_test.transpose(1, 2))

# %%
def forward(self, inputs):
        # predict first roll
        step_pred = self.one_pass(inputs)
        inputs = torch.cat((
            inputs,
            step_pred
        ), dim=1)
        
        for step in range(1, self.regress_steps):
            # take chunk
            train_inputs = inputs[:, step * self.output_length:, :]
            
            # normalize
            T_t = train_inputs[:, 0, :].clone()
            train_inputs = train_inputs - T_t.unsqueeze(1)
            
            Q_t = get_rotation_matrix(train_inputs)
            train_inputs = torch.matmul(train_inputs, Q_t.transpose(1, 2))
            
            # autoregress
            step_pred = self.one_pass(train_inputs)
            
            # revert to original scale
            step_pred = torch.matmul(step_pred, Q_t) + T_t            
            # add new predictions
            inputs = torch.cat((
                inputs,
                step_pred
            ), dim=1)
            
        return inputs[:, self.input_length:, :]

# %% [markdown]
# ### palo-alto

# %%
# Hyperparameter
batch_size = 32
city = 'palo-alto'
model_dim = 24
n_heads = 6
linear_dim = 48 # [32, 128]
dropout_rate = 0 # [0, 0.5]
encoder_layers = 3
num_iters = 100 # [50, 100]
learning_rate = 0.002 # [0.001, 0.005]
factor = 0.5 # 0.1 ~ 0.99
patience = 2
regress_steps = 3

palo_net, palo_loss = train(
    batch_size, 
    city, 
    model_dim,
    n_heads,
    linear_dim,
    dropout_rate,
    encoder_layers,
    regress_steps,
    num_iters,
    learning_rate,
    factor,
    patience,
    device=DEVICE
)
# Out:
# number of weight/biases matrices: 44 for a total of 76648 parameters
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1
# Training & Validating ----------------
# - Training Loss: 187.84058266931189
# - Validation Loss: 96.77792894518053
#
# Epoch 2
# Training & Validating ----------------
# - Training Loss: 77.26652911721068
# - Validation Loss: 67.82978006311365
#
# Epoch 3
# Training & Validating ----------------
# - Training Loss: 56.83359368547841
# - Validation Loss: 51.18654245943637
#
# Epoch 4
# Training & Validating ----------------
# - Training Loss: 49.32752001391674
# - Validation Loss: 49.83748554539036
#
# Epoch 5
# Training & Validating ----------------
# - Training Loss: 45.077818505488096
# - Validation Loss: 46.154568285555456
#
# Epoch 6
# Training & Validating ----------------
# - Training Loss: 41.73312770718991
# - Validation Loss: 44.959601582707585
#
# Epoch 7
# Training & Validating ----------------
# - Training Loss: 39.046695018734354
# - Validation Loss: 36.655150439288164
#
# Epoch 8
# Training & Validating ----------------
# - Training Loss: 37.701488760883095
# - Validation Loss: 34.77015845840042
#
# Epoch 9
# Training & Validating ----------------
# - Training Loss: 36.20554763556234
# - Validation Loss: 36.0502791533599
#
# Epoch 10
# Training & Validating ----------------
# - Training Loss: 34.492602985053814
# - Validation Loss: 34.00851100199932
#
# Epoch 11
# Training & Validating ----------------
# - Training Loss: 33.231987033470446
# - Validation Loss: 31.646763105650205
#
# Epoch 12
# Training & Validating ----------------
# - Training Loss: 35.58365756750814
# - Validation Loss: 40.315571552998314
#
# Epoch 13
# Training & Validating ----------------
# - Training Loss: 33.05893705011475
# - Validation Loss: 30.741387650773333
#
# Epoch 14
# Training & Validating ----------------
# - Training Loss: 42.09223286263667
# - Validation Loss: 37.72017917117557
#
# Epoch 15
# Training & Validating ----------------
# - Training Loss: 34.262110560159655
# - Validation Loss: 32.76839807871226
#
# Epoch 16
# Training & Validating ----------------
# - Training Loss: 33.6779532729695
# - Validation Loss: 32.36264259750779
#
# Epoch    16: reducing learning rate of group 0 to 1.0000e-03.
# Epoch 17
# Training & Validating ----------------
# - Training Loss: 27.5127313229026
# - Validation Loss: 28.799594621400576
#
# Epoch 18
# Training & Validating ----------------
# - Training Loss: 26.428306582419737
# - Validation Loss: 26.662902007231843
#
# Epoch 19
# Training & Validating ----------------
# - Training Loss: 26.39251546831442
# - Validation Loss: 27.873303593815983
#
# Epoch 20
# Training & Validating ----------------
# - Training Loss: 26.766177098192163
# - Validation Loss: 30.06336933857686
#
# Epoch 21
# Training & Validating ----------------
# - Training Loss: 26.248161932834886
# - Validation Loss: 26.927640760267103
#
# Epoch    21: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 22
# Training & Validating ----------------
# - Training Loss: 24.333337568741523
# - Validation Loss: 25.740322783186627
#
# Epoch 23
# Training & Validating ----------------
# - Training Loss: 24.046605704446222
# - Validation Loss: 23.971822790197425
#
# Epoch 24
# Training & Validating ----------------
# - Training Loss: 23.777265927911866
# - Validation Loss: 24.161510312879408
#
# Epoch 25
# Training & Validating ----------------
# - Training Loss: 23.632897456251197
# - Validation Loss: 24.33604521364779
#
# Epoch 26
# Training & Validating ----------------
# - Training Loss: 23.572075546672153
# - Validation Loss: 24.710386559769915
#
# Epoch    26: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 27
# Training & Validating ----------------
# - Training Loss: 22.51215376981288
# - Validation Loss: 23.116910754023372
#
# Epoch 28
# Training & Validating ----------------
# - Training Loss: 22.290170338458054
# - Validation Loss: 22.958861222138275
#
# Epoch 29
# Training & Validating ----------------
# - Training Loss: 22.107543263308017
# - Validation Loss: 22.72150604144947
#
# Epoch 30
# Training & Validating ----------------
# - Training Loss: 21.87893574598635
# - Validation Loss: 22.694848808082373
#
# Epoch 31
# Training & Validating ----------------
# - Training Loss: 21.735674648681098
# - Validation Loss: 22.662284747974294
#
# Epoch 32
# Training & Validating ----------------
# - Training Loss: 21.524584424955556
# - Validation Loss: 22.43981796986348
#
# Epoch 33
# Training & Validating ----------------
# - Training Loss: 21.57521984202218
# - Validation Loss: 22.69825280679239
#
# Epoch 34
# Training & Validating ----------------
# - Training Loss: 21.44458660103093
# - Validation Loss: 22.210601342690957
#
# Epoch 35
# Training & Validating ----------------
# - Training Loss: 21.223887848217338
# - Validation Loss: 22.505111127286344
#
# Epoch 36
# Training & Validating ----------------
# - Training Loss: 21.0917104783327
# - Validation Loss: 22.62715589677965
#
# Epoch 37
# Training & Validating ----------------
# - Training Loss: 21.00353706767368
# - Validation Loss: 22.376206062935495
#
# Epoch    37: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 38
# Training & Validating ----------------
# - Training Loss: 20.496763503869847
# - Validation Loss: 22.361539582948428
#
# Epoch 39
# Training & Validating ----------------
# - Training Loss: 20.282474769682842
# - Validation Loss: 22.326065810951025
#
# Epoch 40
# Training & Validating ----------------
# - Training Loss: 20.153330590675424
# - Validation Loss: 22.368871740392738
#
# Epoch    40: reducing learning rate of group 0 to 6.2500e-05.
# Epoch 41
# Training & Validating ----------------
# - Training Loss: 19.86966922375144
# - Validation Loss: 22.222386025093698
#
# Epoch 42
# Training & Validating ----------------
# - Training Loss: 19.796222579231603
# - Validation Loss: 22.155354628691803
#
# Epoch 43
# Training & Validating ----------------
# - Training Loss: 19.74717029548894
# - Validation Loss: 22.1291199761468
#
# Epoch 44
# Training & Validating ----------------
# - Training Loss: 19.67138124856468
# - Validation Loss: 22.171426824621253
#
# Epoch 45
# Training & Validating ----------------
# - Training Loss: 19.62080805520983
# - Validation Loss: 22.134267420382113
#
# Epoch 46
# Training & Validating ----------------
# - Training Loss: 19.57837719450365
# - Validation Loss: 22.023245759912438
#
# Epoch 47
# Training & Validating ----------------
# - Training Loss: 19.518707187663907
# - Validation Loss: 22.022113748498864
#
# Epoch 48
# Training & Validating ----------------
# - Training Loss: 19.480865113459284
# - Validation Loss: 22.04409764264081
#
# Epoch 49
# Training & Validating ----------------
# - Training Loss: 19.440340206248116
# - Validation Loss: 22.033619236301732
#
# Epoch    49: reducing learning rate of group 0 to 3.1250e-05.
# Epoch 50
# Training & Validating ----------------
# - Training Loss: 19.320165110624863
# - Validation Loss: 21.840566093857223
#
# Epoch 51
# Training & Validating ----------------
# - Training Loss: 19.259795641686868
# - Validation Loss: 21.827175423905658
#
# Epoch 52
# Training & Validating ----------------
# - Training Loss: 19.204126157109744
# - Validation Loss: 21.808982385171426
#
# Epoch 53
# Training & Validating ----------------
# - Training Loss: 19.186678996779445
# - Validation Loss: 21.806360425175846
#
# Epoch 54
# Training & Validating ----------------
# - Training Loss: 19.164953673275004
# - Validation Loss: 21.83015117129764
#
# Epoch 55
# Training & Validating ----------------
# - Training Loss: 19.129174529621793
# - Validation Loss: 21.797547469267975
#
# Epoch 56
# Training & Validating ----------------
# - Training Loss: 19.101760258660473
# - Validation Loss: 21.800268173217773
#
# Epoch 57
# Training & Validating ----------------
# - Training Loss: 19.084628832446363
# - Validation Loss: 21.791393383129222
#
# Epoch 58
# Training & Validating ----------------
# - Training Loss: 19.041547472469883
# - Validation Loss: 21.807144139264082
#
# Epoch 59
# Training & Validating ----------------
# - Training Loss: 19.02112569441074
# - Validation Loss: 21.789553925797748
#
# Epoch 60
# Training & Validating ----------------
# - Training Loss: 19.001979358118437
# - Validation Loss: 21.78869324761468
#
# Epoch 61
# Training & Validating ----------------
# - Training Loss: 18.98095406835086
# - Validation Loss: 21.762907363273
#
# Epoch 62
# Training & Validating ----------------
# - Training Loss: 18.95539126693318
# - Validation Loss: 21.787778313095505
#
# Epoch 63
# Training & Validating ----------------
# - Training Loss: 18.916862377427098
# - Validation Loss: 21.739817000724173
#
# Epoch 64
# Training & Validating ----------------
# - Training Loss: 18.895894905226168
# - Validation Loss: 21.778126665063805
#
# Epoch 65
# Training & Validating ----------------
# - Training Loss: 18.885031768051736
# - Validation Loss: 21.773641689403636
#
# Epoch 66
# Training & Validating ----------------
# - Training Loss: 18.862166455662216
# - Validation Loss: 21.772238370534534
#
# Epoch    66: reducing learning rate of group 0 to 1.5625e-05.
# Epoch 67
# Training & Validating ----------------
# - Training Loss: 18.776617627469296
# - Validation Loss: 21.826970023077887
#
# Epoch 68
# Training & Validating ----------------
# - Training Loss: 18.74989075193773
# - Validation Loss: 21.8049354037723
#
# Epoch 69
# Training & Validating ----------------
# - Training Loss: 18.729494454245184
# - Validation Loss: 21.792382034095557
#
# Epoch    69: reducing learning rate of group 0 to 7.8125e-06.
# Epoch 70
# Training & Validating ----------------
# - Training Loss: 18.672522796721417
# - Validation Loss: 21.8242066099837
#
# Epoch 71
# Training & Validating ----------------
# - Training Loss: 18.649182178146408
# - Validation Loss: 21.829682556358545
#
# Epoch 72
# Training & Validating ----------------
# - Training Loss: 18.638954519164315
# - Validation Loss: 21.826453621323044
#
# Epoch    72: reducing learning rate of group 0 to 3.9063e-06.
# Epoch 73
# Training & Validating ----------------
# - Training Loss: 18.604873190294033
# - Validation Loss: 21.820424878919447
#
# Epoch 74
# Training & Validating ----------------
# - Training Loss: 18.594767745949042
# - Validation Loss: 21.814070392299342
#
# Epoch 75
# Training & Validating ----------------
# - Training Loss: 18.58682829689909
# - Validation Loss: 21.81393744494464
#
# Epoch    75: reducing learning rate of group 0 to 1.9531e-06.
# Epoch 76
# Training & Validating ----------------
# - Training Loss: 18.56692499789003
# - Validation Loss: 21.794866613439613
#
# Epoch 77
# Training & Validating ----------------
# - Training Loss: 18.55975323402563
# - Validation Loss: 21.7906771737176
#
# Epoch 78
# Training & Validating ----------------
# - Training Loss: 18.55546560485568
# - Validation Loss: 21.790980055525495
#
# Epoch    78: reducing learning rate of group 0 to 9.7656e-07.
# Epoch 79
# Training & Validating ----------------
# - Training Loss: 18.54481708402096
# - Validation Loss: 21.77605708869728
#
# Epoch 80
# Training & Validating ----------------
# - Training Loss: 18.540985161189862
# - Validation Loss: 21.773638751055742
#
# Epoch 81
# Training & Validating ----------------
# - Training Loss: 18.53898300827434
# - Validation Loss: 21.773138020489668
#
# Epoch    81: reducing learning rate of group 0 to 4.8828e-07.
# Epoch 82
# Training & Validating ----------------
# - Training Loss: 18.532576224216722
# - Validation Loss: 21.76637329926362
#
# Epoch 83
# Training & Validating ----------------
# - Training Loss: 18.53066601456096
# - Validation Loss: 21.765168241552406
#
# Epoch 84
# Training & Validating ----------------
# - Training Loss: 18.529679864379702
# - Validation Loss: 21.76457588092701
#
# Epoch    84: reducing learning rate of group 0 to 2.4414e-07.
# Epoch 85
# Training & Validating ----------------
# - Training Loss: 18.525889620229115
# - Validation Loss: 21.761942992339264
#
# Epoch 86
# Training & Validating ----------------
# - Training Loss: 18.52512419046917
# - Validation Loss: 21.761226834477604
#
# Epoch 87
# Training & Validating ----------------
# - Training Loss: 18.524612339031094
# - Validation Loss: 21.76084701434986
#
# Epoch    87: reducing learning rate of group 0 to 1.2207e-07.
# Epoch 88
# Training & Validating ----------------
# - Training Loss: 18.522578663925035
# - Validation Loss: 21.75987519444646
#
# Epoch 89
# Training & Validating ----------------
# - Training Loss: 18.522250747114686
# - Validation Loss: 21.759380392126136
#
# Epoch 90
# Training & Validating ----------------
# - Training Loss: 18.522005451892888
# - Validation Loss: 21.759046941190153
#
# Epoch    90: reducing learning rate of group 0 to 6.1035e-08.
# Epoch 91
# Training & Validating ----------------
# - Training Loss: 18.520927177338642
# - Validation Loss: 21.75867003363532
#
# Epoch 92
# Training & Validating ----------------
# - Training Loss: 18.5207940704391
# - Validation Loss: 21.758415814992542
#
# Epoch 93
# Training & Validating ----------------
# - Training Loss: 18.520680107773234
# - Validation Loss: 21.75821355871252
#
# Epoch    93: reducing learning rate of group 0 to 3.0518e-08.
# Epoch 94
# Training & Validating ----------------
# - Training Loss: 18.520107707920697
# - Validation Loss: 21.75810380884119
#
# Epoch 95
# Training & Validating ----------------
# - Training Loss: 18.5200560227346
# - Validation Loss: 21.758002229639
#
# Epoch 96
# Training & Validating ----------------
# - Training Loss: 18.51999883906424
# - Validation Loss: 21.757918589823955
#
# Epoch    96: reducing learning rate of group 0 to 1.5259e-08.
# Epoch 97
# Training & Validating ----------------
# - Training Loss: 18.519696940300374
# - Validation Loss: 21.75789992873733
#
# Epoch 98
# Training & Validating ----------------
# - Training Loss: 18.519675784011977
# - Validation Loss: 21.757881061450856
#
# Epoch 99
# Training & Validating ----------------
# - Training Loss: 18.5196548597749
# - Validation Loss: 21.757866318161422
#
# Epoch 100
# Training & Validating ----------------
# - Training Loss: 18.519634580753678
# - Validation Loss: 21.757851445997083

# %%
plot_loss(2, 'Palo-Alto', 'train', palo_loss)

# %%
vis_results('palo-alto', 'train', 32, palo_net, 25)
